# %% [markdown]
# # Obtain SNP Data

# %% [markdown]
# ## Download and install bgenix
# ### see https://enkre.net/cgi-bin/code/bgen/doc/trunk/doc/wiki/bgenix.md

# %%
cd /opt/notebooks
wget http://code.enkre.net/bgen/tarball/release/bgen.tgz
tar xvfz bgen.tgz > /dev/null
cd bgen.tgz/
./waf configure 
./waf 
./build/test/unit/test_bgen
./build/apps/bgenix -g example/example.16bits.bgen –list
cd /opt/notebooks
# Out:
# --2022-09-27 07:26:07--  http://code.enkre.net/bgen/tarball/release/bgen.tgz
# Resolving code.enkre.net (code.enkre.net)... 91.197.228.37
# Connecting to code.enkre.net (code.enkre.net)|91.197.228.37|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://enkre.net/cgi-bin/code/bgen/tarball/release/bgen.tgz [following]
# --2022-09-27 07:26:07--  https://enkre.net/cgi-bin/code/bgen/tarball/release/bgen.tgz
# Resolving enkre.net (enkre.net)... 91.197.228.37
# Connecting to enkre.net (enkre.net)|91.197.228.37|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25476745 (24M) [application/x-compressed]
# Saving to: ‘bgen.tgz’
#
# bgen.tgz            100%[===================>]  24.30M  43.5MB/s    in 0.6s
#
# 2022-09-27 07:26:25 (43.5 MB/s) - ‘bgen.tgz’ saved [25476745/25476745]
#
# Setting top to                           : /opt/notebooks/bgen.tgz
# Setting out to                           : /opt/notebooks/bgen.tgz/build
# Checking for 'gcc' (C compiler)          : /usr/bin/gcc
# Checking for 'g++' (C++ compiler)        : /usr/bin/g++
# zlib                                     : yes
# rt                                       : yes
# pthread                                  : yes
# dl                                       : yes
# 'configure' finished successfully (0.653s)
# Waf: Entering directory `/opt/notebooks/bgen.tgz/build'
# Creating release build...
# [ 1/85] Compiling 3rd_party/boost_1_55_0/libs/filesystem/src/path.cpp
# [ 2/85] Compiling 3rd_party/boost_1_55_0/libs/filesystem/src/operations.cpp
# [ 3/85] Compiling 3rd_party/boost_1_55_0/libs/chrono/src/thread_clock.cpp
# [ 4/85] Compiling 3rd_party/boost_1_55_0/libs/filesystem/src/codecvt_error_category.cpp
# [ 5/85] Compiling 3rd_party/boost_1_55_0/libs/chrono/src/process_cpu_clocks.cpp
# [ 6/85] Compiling 3rd_party/boost_1_55_0/libs/thread/src/pthread/thread.cpp
# [ 7/85] Compiling 3rd_party/boost_1_55_0/libs/chrono/src/chrono.cpp
# [ 8/85] Compiling 3rd_party/boost_1_55_0/libs/timer/src/cpu_timer.cpp
# ../3rd_party/boost_1_55_0/libs/filesystem/src/operations.cpp:323:8: warning: ‘bool {anonymous}::error(bool, const boost::system::error_code&, const boost::filesystem::path&, const boost::filesystem::path&, boost::system::error_code*, const string&)’ defined but not used [-Wunused-function]
#    bool error(bool was_error, const error_code& result,
#         ^~~~~
# cc1plus: warning: unrecognized command line option ‘-Wno-keyword-macro’
# cc1plus: warning: unrecognized command line option ‘-Wno-c++11-long-long’
# cc1plus: warning: unrecognized command line option ‘-Wno-c++11-long-long’
#
# [ 9/85] Compiling 3rd_party/boost_1_55_0/libs/timer/src/auto_timers_construction.cpp
# [10/85] Compiling 3rd_party/boost_1_55_0/libs/filesystem/src/utf8_codecvt_facet.cpp
# [11/85] Compiling 3rd_party/boost_1_55_0/libs/filesystem/src/path_traits.cpp
# [12/85] Compiling 3rd_party/boost_1_55_0/libs/system/src/error_code.cpp
# [13/85] Compiling 3rd_party/boost_1_55_0/libs/filesystem/src/windows_file_codecvt.cpp
# [14/85] Compiling 3rd_party/boost_1_55_0/libs/thread/src/pthread/once_atomic.cpp
# [15/85] Compiling 3rd_party/boost_1_55_0/libs/thread/src/tss_null.cpp
# [16/85] Compiling 3rd_party/boost_1_55_0/libs/filesystem/src/portability.cpp
# [17/85] Compiling 3rd_party/boost_1_55_0/libs/date_time/src/posix_time/posix_time_types.cpp
# [18/85] Compiling 3rd_party/boost_1_55_0/libs/filesystem/src/unique_path.cpp
# [19/85] Compiling 3rd_party/boost_1_55_0/libs/thread/src/future.cpp
# [20/85] Compiling 3rd_party/sqlite3/sqlite3/sqlite3.c
# [21/85] Compiling 3rd_party/zstd-1.1.0/lib/common/zstd_common.c
# [22/85] Compiling 3rd_party/zstd-1.1.0/lib/compress/zbuff_compress.c
# [23/85] Compiling 3rd_party/zstd-1.1.0/lib/common/xxhash.c
# [24/85] Compiling 3rd_party/zstd-1.1.0/lib/common/fse_decompress.c
# [25/85] Compiling 3rd_party/zstd-1.1.0/lib/decompress/zbuff_decompress.c
# [26/85] Compiling 3rd_party/zstd-1.1.0/lib/common/entropy_common.c
# [27/85] Compiling 3rd_party/zstd-1.1.0/lib/compress/zstd_compress.c
# [28/85] Compiling 3rd_party/zstd-1.1.0/lib/compress/fse_compress.c
# [29/85] Compiling 3rd_party/zstd-1.1.0/lib/decompress/huf_decompress.c
# [30/85] Linking build/3rd_party/boost_1_55_0/libboost.a
# [31/85] Compiling 3rd_party/zstd-1.1.0/lib/compress/huf_compress.c
# [32/85] Compiling 3rd_party/zstd-1.1.0/lib/decompress/zstd_decompress.c
# [33/85] Compiling db/src/Error.cpp
# [34/85] Compiling db/src/SQLStatement.cpp
# [35/85] Compiling db/src/SQLite3Connection.cpp
# [36/85] Compiling db/src/SQLite3Statement.cpp
# [37/85] Compiling db/src/Connection.cpp
# [38/85] Compiling src/View.cpp
# [39/85] Compiling src/zlib.cpp
# [40/85] Compiling src/IndexQuery.cpp
# [41/85] Compiling src/bgen.cpp
# [42/85] Compiling src/MissingValue.cpp
# [43/85] Linking build/3rd_party/zstd-1.1.0/libzstd.a
# [44/85] Compiling appcontext/src/CmdLineOptionProcessor.cpp
# [45/85] Compiling appcontext/src/OptionProcessor.cpp
# ../src/View.cpp: In member function ‘void genfile::bgen::View::setup(const string&)’:
# ../src/View.cpp:212:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#     if( m_stream->gcount() != m_postheader_data.size() ) {
#         ~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~
# At global scope:
# cc1plus: warning: unrecognized command line option ‘-Wno-c++11-long-long’
#
# [46/85] Compiling appcontext/src/ApplicationContext.cpp
# [47/85] Compiling appcontext/src/OptionDefinition.cpp
# [48/85] Compiling appcontext/src/get_current_time_as_string.cpp
# [49/85] Compiling appcontext/src/OstreamTee.cpp
# [50/85] Compiling appcontext/src/progress_bar.cpp
# [51/85] Compiling appcontext/src/CmdLineUIContext.cpp
# [52/85] Compiling appcontext/src/string_utils.cpp
# [53/85] Compiling appcontext/src/Timer.cpp
# [54/85] Compiling appcontext/src/UIContext.cpp
# [55/85] Compiling example/bgen_to_vcf.cpp
# [56/85] Compiling example/count_alleles.cpp
# [57/85] Compiling example/compute_expected_dosage.cpp
# In file included from ../example/bgen_to_vcf.cpp:12:0:
# ../genfile/include/genfile/bgen/bgen.hpp: In instantiation of ‘void genfile::bgen::v12::parse_probability_data_general(const genfile::bgen::v12::GenotypeDataBlock&, BitParser, const genfile::bgen::Context&, Setter&) [with Setter = ProbSetter; BitParser = genfile::bgen::v12::impl::SpecialisedBitParser<8>]’:
# ../genfile/include/genfile/bgen/bgen.hpp:1099:38:   required from ‘void genfile::bgen::v12::parse_probability_data(const genfile::bgen::v12::GenotypeDataBlock&, Setter&) [with Setter = ProbSetter]’
# ../genfile/include/genfile/bgen/bgen.hpp:1053:27:   required from ‘void genfile::bgen::v12::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = ProbSetter; genfile::byte_t = unsigned char]’
# ../genfile/include/genfile/bgen/bgen.hpp:1628:32:   required from ‘void genfile::bgen::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = ProbSetter; genfile::byte_t = unsigned char]’
# ../genfile/include/genfile/bgen/bgen.hpp:1642:26:   required from ‘void genfile::bgen::read_and_parse_genotype_data_block(std::istream&, const genfile::bgen::Context&, Setter&, std::vector<unsigned char>*, std::vector<unsigned char>*) [with Setter = ProbSetter; std::istream = std::basic_istream<char>]’
# ../example/bgen_to_vcf.cpp:189:3:   required from here
# ../genfile/include/genfile/bgen/bgen.hpp:1265:42: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for( uint32_t allele = 0; allele < (pack.numberOfAlleles-1); ++allele ) {
#                                    ~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~
# ../genfile/include/genfile/bgen/bgen.hpp: In instantiation of ‘void genfile::bgen::v12::parse_probability_data_general(const genfile::bgen::v12::GenotypeDataBlock&, BitParser, const genfile::bgen::Context&, Setter&) [with Setter = ProbSetter; BitParser = genfile::bgen::v12::impl::SpecialisedBitParser<16>]’:
# ../genfile/include/genfile/bgen/bgen.hpp:1107:38:   required from ‘void genfile::bgen::v12::parse_probability_data(const genfile::bgen::v12::GenotypeDataBlock&, Setter&) [with Setter = ProbSetter]’
# ../genfile/include/genfile/bgen/bgen.hpp:1053:27:   required from ‘void genfile::bgen::v12::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = ProbSetter; genfile::byte_t = unsigned char]’
# ../genfile/include/genfile/bgen/bgen.hpp:1628:32:   required from ‘void genfile::bgen::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = ProbSetter; genfile::byte_t = unsigned char]’
# ../genfile/include/genfile/bgen/bgen.hpp:1642:26:   required from ‘void genfile::bgen::read_and_parse_genotype_data_block(std::istream&, const genfile::bgen::Context&, Setter&, std::vector<unsigned char>*, std::vector<unsigned char>*) [with Setter = ProbSetter; std::istream = std::basic_istream<char>]’
# ../example/bgen_to_vcf.cpp:189:3:   required from here
# ../genfile/include/genfile/bgen/bgen.hpp:1265:42: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# ../genfile/include/genfile/bgen/bgen.hpp: In instantiation of ‘void genfile::bgen::v12::parse_probability_data_general(const genfile::bgen::v12::GenotypeDataBlock&, BitParser, const genfile::bgen::Context&, Setter&) [with Setter = ProbSetter; BitParser = genfile::bgen::v12::impl::BitParser]’:
# ../genfile/include/genfile/bgen/bgen.hpp:1115:38:   required from ‘void genfile::bgen::v12::parse_probability_data(const genfile::bgen::v12::GenotypeDataBlock&, Setter&) [with Setter = ProbSetter]’
# ../genfile/include/genfile/bgen/bgen.hpp:1053:27:   required from ‘void genfile::bgen::v12::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = ProbSetter; genfile::byte_t = unsigned char]’
# ../genfile/include/genfile/bgen/bgen.hpp:1628:32:   required from ‘void genfile::bgen::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = ProbSetter; genfile::byte_t = unsigned char]’
# ../genfile/include/genfile/bgen/bgen.hpp:1642:26:   required from ‘void genfile::bgen::read_and_parse_genotype_data_block(std::istream&, const genfile::bgen::Context&, Setter&, std::vector<unsigned char>*, std::vector<unsigned char>*) [with Setter = ProbSetter; std::istream = std::basic_istream<char>]’
# ../example/bgen_to_vcf.cpp:189:3:   required from here
# ../genfile/include/genfile/bgen/bgen.hpp:1265:42: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-c++11-long-long’
#
# [58/85] Linking build/appcontext/libappcontext.a
# [59/85] Compiling test/unit/test_variant_data_block.cpp
# In file included from ../example/compute_expected_dosage.cpp:12:0:
# ../genfile/include/genfile/bgen/bgen.hpp: In instantiation of ‘void genfile::bgen::v12::parse_probability_data_general(const genfile::bgen::v12::GenotypeDataBlock&, BitParser, const genfile::bgen::Context&, Setter&) [with Setter = DosageSetter; BitParser = genfile::bgen::v12::impl::SpecialisedBitParser<8>]’:
# ../genfile/include/genfile/bgen/bgen.hpp:1099:38:   required from ‘void genfile::bgen::v12::parse_probability_data(const genfile::bgen::v12::GenotypeDataBlock&, Setter&) [with Setter = DosageSetter]’
# ../genfile/include/genfile/bgen/bgen.hpp:1053:27:   required from ‘void genfile::bgen::v12::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = DosageSetter; genfile::byte_t = unsigned char]’
# ../genfile/include/genfile/bgen/bgen.hpp:1628:32:   required from ‘void genfile::bgen::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = DosageSetter; genfile::byte_t = unsigned char]’
# ../genfile/include/genfile/bgen/bgen.hpp:1642:26:   required from ‘void genfile::bgen::read_and_parse_genotype_data_block(std::istream&, const genfile::bgen::Context&, Setter&, std::vector<unsigned char>*, std::vector<unsigned char>*) [with Setter = DosageSetter; std::istream = std::basic_istream<char>]’
# ../genfile/include/genfile/bgen/View.hpp:87:68:   required from ‘void genfile::bgen::View::read_genotype_data_block(ProbSetter&) [with ProbSetter = DosageSetter]’
# ../example/compute_expected_dosage.cpp:144:37:   required from here
# ../genfile/include/genfile/bgen/bgen.hpp:1265:42: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for( uint32_t allele = 0; allele < (pack.numberOfAlleles-1); ++allele ) {
#                                    ~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~
# ../genfile/include/genfile/bgen/bgen.hpp: In instantiation of ‘void genfile::bgen::v12::parse_probability_data_general(const genfile::bgen::v12::GenotypeDataBlock&, BitParser, const genfile::bgen::Context&, Setter&) [with Setter = DosageSetter; BitParser = genfile::bgen::v12::impl::SpecialisedBitParser<16>]’:
# ../genfile/include/genfile/bgen/bgen.hpp:1107:38:   required from ‘void genfile::bgen::v12::parse_probability_data(const genfile::bgen::v12::GenotypeDataBlock&, Setter&) [with Setter = DosageSetter]’
# ../genfile/include/genfile/bgen/bgen.hpp:1053:27:   required from ‘void genfile::bgen::v12::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = DosageSetter; genfile::byte_t = unsigned char]’
# ../genfile/include/genfile/bgen/bgen.hpp:1628:32:   required from ‘void genfile::bgen::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = DosageSetter; genfile::byte_t = unsigned char]’
# ../genfile/include/genfile/bgen/bgen.hpp:1642:26:   required from ‘void genfile::bgen::read_and_parse_genotype_data_block(std::istream&, const genfile::bgen::Context&, Setter&, std::vector<unsigned char>*, std::vector<unsigned char>*) [with Setter = DosageSetter; std::istream = std::basic_istream<char>]’
# ../genfile/include/genfile/bgen/View.hpp:87:68:   required from ‘void genfile::bgen::View::read_genotype_data_block(ProbSetter&) [with ProbSetter = DosageSetter]’
# ../example/compute_expected_dosage.cpp:144:37:   required from here
# ../genfile/include/genfile/bgen/bgen.hpp:1265:42: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# ../genfile/include/genfile/bgen/bgen.hpp: In instantiation of ‘void genfile::bgen::v12::parse_probability_data_general(const genfile::bgen::v12::GenotypeDataBlock&, BitParser, const genfile::bgen::Context&, Setter&) [with Setter = DosageSetter; BitParser = genfile::bgen::v12::impl::BitParser]’:
# ../genfile/include/genfile/bgen/bgen.hpp:1115:38:   required from ‘void genfile::bgen::v12::parse_probability_data(const genfile::bgen::v12::GenotypeDataBlock&, Setter&) [with Setter = DosageSetter]’
# ../genfile/include/genfile/bgen/bgen.hpp:1053:27:   required from ‘void genfile::bgen::v12::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = DosageSetter; genfile::byte_t = unsigned char]’
# ../genfile/include/genfile/bgen/bgen.hpp:1628:32:   required from ‘void genfile::bgen::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = DosageSetter; genfile::byte_t = unsigned char]’
# ../genfile/include/genfile/bgen/bgen.hpp:1642:26:   required from ‘void genfile::bgen::read_and_parse_genotype_data_block(std::istream&, const genfile::bgen::Context&, Setter&, std::vector<unsigned char>*, std::vector<unsigned char>*) [with Setter = DosageSetter; std::istream = std::basic_istream<char>]’
# ../genfile/include/genfile/bgen/View.hpp:87:68:   required from ‘void genfile::bgen::View::read_genotype_data_block(ProbSetter&) [with ProbSetter = DosageSetter]’
# ../example/compute_expected_dosage.cpp:144:37:   required from here
# ../genfile/include/genfile/bgen/bgen.hpp:1265:42: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-c++11-long-long’
#
# [60/85] Compiling test/unit/test_utils.cpp
# [61/85] Compiling test/unit/main.cpp
# In file included from ../test/unit/test_variant_data_block.cpp:20:0:
# ../genfile/include/genfile/bgen/bgen.hpp: In instantiation of ‘void genfile::bgen::v12::parse_probability_data_general(const genfile::bgen::v12::GenotypeDataBlock&, BitParser, const genfile::bgen::Context&, Setter&) [with Setter = ProbSetCheck; BitParser = genfile::bgen::v12::impl::SpecialisedBitParser<8>]’:
# ../genfile/include/genfile/bgen/bgen.hpp:1099:38:   required from ‘void genfile::bgen::v12::parse_probability_data(const genfile::bgen::v12::GenotypeDataBlock&, Setter&) [with Setter = ProbSetCheck]’
# ../genfile/include/genfile/bgen/bgen.hpp:1053:27:   required from ‘void genfile::bgen::v12::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = ProbSetCheck; genfile::byte_t = unsigned char]’
# ../genfile/include/genfile/bgen/bgen.hpp:1628:32:   required from ‘void genfile::bgen::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = ProbSetCheck; genfile::byte_t = unsigned char]’
# ../test/unit/test_variant_data_block.cpp:505:3:   required from here
# ../genfile/include/genfile/bgen/bgen.hpp:1265:42: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for( uint32_t allele = 0; allele < (pack.numberOfAlleles-1); ++allele ) {
#                                    ~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~
# ../genfile/include/genfile/bgen/bgen.hpp: In instantiation of ‘void genfile::bgen::v12::parse_probability_data_general(const genfile::bgen::v12::GenotypeDataBlock&, BitParser, const genfile::bgen::Context&, Setter&) [with Setter = ProbSetCheck; BitParser = genfile::bgen::v12::impl::SpecialisedBitParser<16>]’:
# ../genfile/include/genfile/bgen/bgen.hpp:1107:38:   required from ‘void genfile::bgen::v12::parse_probability_data(const genfile::bgen::v12::GenotypeDataBlock&, Setter&) [with Setter = ProbSetCheck]’
# ../genfile/include/genfile/bgen/bgen.hpp:1053:27:   required from ‘void genfile::bgen::v12::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = ProbSetCheck; genfile::byte_t = unsigned char]’
# ../genfile/include/genfile/bgen/bgen.hpp:1628:32:   required from ‘void genfile::bgen::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = ProbSetCheck; genfile::byte_t = unsigned char]’
# ../test/unit/test_variant_data_block.cpp:505:3:   required from here
# ../genfile/include/genfile/bgen/bgen.hpp:1265:42: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# ../genfile/include/genfile/bgen/bgen.hpp: In instantiation of ‘void genfile::bgen::v12::parse_probability_data_general(const genfile::bgen::v12::GenotypeDataBlock&, BitParser, const genfile::bgen::Context&, Setter&) [with Setter = ProbSetCheck; BitParser = genfile::bgen::v12::impl::BitParser]’:
# ../genfile/include/genfile/bgen/bgen.hpp:1115:38:   required from ‘void genfile::bgen::v12::parse_probability_data(const genfile::bgen::v12::GenotypeDataBlock&, Setter&) [with Setter = ProbSetCheck]’
# ../genfile/include/genfile/bgen/bgen.hpp:1053:27:   required from ‘void genfile::bgen::v12::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = ProbSetCheck; genfile::byte_t = unsigned char]’
# ../genfile/include/genfile/bgen/bgen.hpp:1628:32:   required from ‘void genfile::bgen::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = ProbSetCheck; genfile::byte_t = unsigned char]’
# ../test/unit/test_variant_data_block.cpp:505:3:   required from here
# ../genfile/include/genfile/bgen/bgen.hpp:1265:42: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-c++11-long-long’
#
# [62/85] Compiling test/unit/test_bgen_snp_format.cpp
# In file included from ../example/count_alleles.cpp:15:0:
# ../genfile/include/genfile/bgen/bgen.hpp: In instantiation of ‘void genfile::bgen::v12::parse_probability_data_general(const genfile::bgen::v12::GenotypeDataBlock&, BitParser, const genfile::bgen::Context&, Setter&) [with Setter = AlleleCounter; BitParser = genfile::bgen::v12::impl::SpecialisedBitParser<8>]’:
# ../genfile/include/genfile/bgen/bgen.hpp:1099:38:   required from ‘void genfile::bgen::v12::parse_probability_data(const genfile::bgen::v12::GenotypeDataBlock&, Setter&) [with Setter = AlleleCounter]’
# ../genfile/include/genfile/bgen/bgen.hpp:1053:27:   required from ‘void genfile::bgen::v12::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = AlleleCounter; genfile::byte_t = unsigned char]’
# ../genfile/include/genfile/bgen/bgen.hpp:1628:32:   required from ‘void genfile::bgen::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = AlleleCounter; genfile::byte_t = unsigned char]’
# ../genfile/include/genfile/bgen/bgen.hpp:1642:26:   required from ‘void genfile::bgen::read_and_parse_genotype_data_block(std::istream&, const genfile::bgen::Context&, Setter&, std::vector<unsigned char>*, std::vector<unsigned char>*) [with Setter = AlleleCounter; std::istream = std::basic_istream<char>]’
# ../genfile/include/genfile/bgen/View.hpp:87:68:   required from ‘void genfile::bgen::View::read_genotype_data_block(ProbSetter&) [with ProbSetter = AlleleCounter]’
# ../example/count_alleles.cpp:262:55:   required from here
# ../genfile/include/genfile/bgen/bgen.hpp:1265:42: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for( uint32_t allele = 0; allele < (pack.numberOfAlleles-1); ++allele ) {
#                                    ~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~
# ../genfile/include/genfile/bgen/bgen.hpp: In instantiation of ‘void genfile::bgen::v12::parse_probability_data_general(const genfile::bgen::v12::GenotypeDataBlock&, BitParser, const genfile::bgen::Context&, Setter&) [with Setter = AlleleCounter; BitParser = genfile::bgen::v12::impl::SpecialisedBitParser<16>]’:
# ../genfile/include/genfile/bgen/bgen.hpp:1107:38:   required from ‘void genfile::bgen::v12::parse_probability_data(const genfile::bgen::v12::GenotypeDataBlock&, Setter&) [with Setter = AlleleCounter]’
# ../genfile/include/genfile/bgen/bgen.hpp:1053:27:   required from ‘void genfile::bgen::v12::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = AlleleCounter; genfile::byte_t = unsigned char]’
# ../genfile/include/genfile/bgen/bgen.hpp:1628:32:   required from ‘void genfile::bgen::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = AlleleCounter; genfile::byte_t = unsigned char]’
# ../genfile/include/genfile/bgen/bgen.hpp:1642:26:   required from ‘void genfile::bgen::read_and_parse_genotype_data_block(std::istream&, const genfile::bgen::Context&, Setter&, std::vector<unsigned char>*, std::vector<unsigned char>*) [with Setter = AlleleCounter; std::istream = std::basic_istream<char>]’
# ../genfile/include/genfile/bgen/View.hpp:87:68:   required from ‘void genfile::bgen::View::read_genotype_data_block(ProbSetter&) [with ProbSetter = AlleleCounter]’
# ../example/count_alleles.cpp:262:55:   required from here
# ../genfile/include/genfile/bgen/bgen.hpp:1265:42: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# ../genfile/include/genfile/bgen/bgen.hpp: In instantiation of ‘void genfile::bgen::v12::parse_probability_data_general(const genfile::bgen::v12::GenotypeDataBlock&, BitParser, const genfile::bgen::Context&, Setter&) [with Setter = AlleleCounter; BitParser = genfile::bgen::v12::impl::BitParser]’:
# ../genfile/include/genfile/bgen/bgen.hpp:1115:38:   required from ‘void genfile::bgen::v12::parse_probability_data(const genfile::bgen::v12::GenotypeDataBlock&, Setter&) [with Setter = AlleleCounter]’
# ../genfile/include/genfile/bgen/bgen.hpp:1053:27:   required from ‘void genfile::bgen::v12::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = AlleleCounter; genfile::byte_t = unsigned char]’
# ../genfile/include/genfile/bgen/bgen.hpp:1628:32:   required from ‘void genfile::bgen::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = AlleleCounter; genfile::byte_t = unsigned char]’
# ../genfile/include/genfile/bgen/bgen.hpp:1642:26:   required from ‘void genfile::bgen::read_and_parse_genotype_data_block(std::istream&, const genfile::bgen::Context&, Setter&, std::vector<unsigned char>*, std::vector<unsigned char>*) [with Setter = AlleleCounter; std::istream = std::basic_istream<char>]’
# ../genfile/include/genfile/bgen/View.hpp:87:68:   required from ‘void genfile::bgen::View::read_genotype_data_block(ProbSetter&) [with ProbSetter = AlleleCounter]’
# ../example/count_alleles.cpp:262:55:   required from here
# ../genfile/include/genfile/bgen/bgen.hpp:1265:42: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-c++11-long-long’
#
# [63/85] Compiling test/unit/ProbSetCheck.cpp
# [64/85] Compiling test/unit/test_bgen_header_format.cpp
# [65/85] Compiling test/unit/test_little_endian.cpp
# In file included from ../test/unit/test_bgen_snp_format.cpp:20:0:
# ../genfile/include/genfile/bgen/bgen.hpp: In instantiation of ‘void genfile::bgen::v12::parse_probability_data_general(const genfile::bgen::v12::GenotypeDataBlock&, BitParser, const genfile::bgen::Context&, Setter&) [with Setter = ProbSetCheck; BitParser = genfile::bgen::v12::impl::SpecialisedBitParser<8>]’:
# ../genfile/include/genfile/bgen/bgen.hpp:1099:38:   required from ‘void genfile::bgen::v12::parse_probability_data(const genfile::bgen::v12::GenotypeDataBlock&, Setter&) [with Setter = ProbSetCheck]’
# ../genfile/include/genfile/bgen/bgen.hpp:1053:27:   required from ‘void genfile::bgen::v12::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = ProbSetCheck; genfile::byte_t = unsigned char]’
# ../genfile/include/genfile/bgen/bgen.hpp:1628:32:   required from ‘void genfile::bgen::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = ProbSetCheck; genfile::byte_t = unsigned char]’
# ../genfile/include/genfile/bgen/bgen.hpp:1642:26:   required from ‘void genfile::bgen::read_and_parse_genotype_data_block(std::istream&, const genfile::bgen::Context&, Setter&, std::vector<unsigned char>*, std::vector<unsigned char>*) [with Setter = ProbSetCheck; std::istream = std::basic_istream<char>]’
# ../test/unit/test_bgen_snp_format.cpp:556:2:   required from here
# ../genfile/include/genfile/bgen/bgen.hpp:1265:42: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for( uint32_t allele = 0; allele < (pack.numberOfAlleles-1); ++allele ) {
#                                    ~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~
# ../genfile/include/genfile/bgen/bgen.hpp: In instantiation of ‘void genfile::bgen::v12::parse_probability_data_general(const genfile::bgen::v12::GenotypeDataBlock&, BitParser, const genfile::bgen::Context&, Setter&) [with Setter = ProbSetCheck; BitParser = genfile::bgen::v12::impl::SpecialisedBitParser<16>]’:
# ../genfile/include/genfile/bgen/bgen.hpp:1107:38:   required from ‘void genfile::bgen::v12::parse_probability_data(const genfile::bgen::v12::GenotypeDataBlock&, Setter&) [with Setter = ProbSetCheck]’
# ../genfile/include/genfile/bgen/bgen.hpp:1053:27:   required from ‘void genfile::bgen::v12::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = ProbSetCheck; genfile::byte_t = unsigned char]’
# ../genfile/include/genfile/bgen/bgen.hpp:1628:32:   required from ‘void genfile::bgen::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = ProbSetCheck; genfile::byte_t = unsigned char]’
# ../genfile/include/genfile/bgen/bgen.hpp:1642:26:   required from ‘void genfile::bgen::read_and_parse_genotype_data_block(std::istream&, const genfile::bgen::Context&, Setter&, std::vector<unsigned char>*, std::vector<unsigned char>*) [with Setter = ProbSetCheck; std::istream = std::basic_istream<char>]’
# ../test/unit/test_bgen_snp_format.cpp:556:2:   required from here
# ../genfile/include/genfile/bgen/bgen.hpp:1265:42: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# ../genfile/include/genfile/bgen/bgen.hpp: In instantiation of ‘void genfile::bgen::v12::parse_probability_data_general(const genfile::bgen::v12::GenotypeDataBlock&, BitParser, const genfile::bgen::Context&, Setter&) [with Setter = ProbSetCheck; BitParser = genfile::bgen::v12::impl::BitParser]’:
# ../genfile/include/genfile/bgen/bgen.hpp:1115:38:   required from ‘void genfile::bgen::v12::parse_probability_data(const genfile::bgen::v12::GenotypeDataBlock&, Setter&) [with Setter = ProbSetCheck]’
# ../genfile/include/genfile/bgen/bgen.hpp:1053:27:   required from ‘void genfile::bgen::v12::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = ProbSetCheck; genfile::byte_t = unsigned char]’
# ../genfile/include/genfile/bgen/bgen.hpp:1628:32:   required from ‘void genfile::bgen::parse_probability_data(const byte_t*, const byte_t*, const genfile::bgen::Context&, Setter&) [with Setter = ProbSetCheck; genfile::byte_t = unsigned char]’
# ../genfile/include/genfile/bgen/bgen.hpp:1642:26:   required from ‘void genfile::bgen::read_and_parse_genotype_data_block(std::istream&, const genfile::bgen::Context&, Setter&, std::vector<unsigned char>*, std::vector<unsigned char>*) [with Setter = ProbSetCheck; std::istream = std::basic_istream<char>]’
# ../test/unit/test_bgen_snp_format.cpp:556:2:   required from here
# ../genfile/include/genfile/bgen/bgen.hpp:1265:42: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# cc1plus: warning: unrecognized command line option ‘-Wno-c++11-long-long’
#
# [66/85] Creating build/bgen_revision_autogenerated.txt
# /bin/sh: 1: fossil: not found
#
# [67/85] Creating build/bgen_revision_autogenerated.hpp
# [68/85] Compiling src/IndexQuery.cpp
# [69/85] Compiling src/MissingValue.cpp
# [70/85] Compiling src/View.cpp
# [71/85] Compiling src/bgen.cpp
# [72/85] Compiling src/zlib.cpp
# [73/85] Compiling apps/cat-bgen.cpp
# [74/85] Compiling apps/bgenix.cpp
# [75/85] Compiling apps/edit-bgen.cpp
# [76/85] Linking build/3rd_party/sqlite3/libsqlite3.a
# [77/85] Linking build/db/libdb.a
# [78/85] Linking build/libbgen.a
# [79/85] Linking build/apps/cat-bgen
# [80/85] Linking build/example/bgen_to_vcf
# [81/85] Linking build/example/count_alleles
# [82/85] Linking build/example/compute_expected_dosage
# [83/85] Linking build/test/unit/test_bgen
# [84/85] Linking build/apps/edit-bgen
# In file included from /usr/include/c++/7/cassert:44:0,
#                  from ../db/include/db/SQLite3Statement.hpp:10,
#                  from ../db/include/db/sqlite3.hpp:12,
#                  from ../genfile/include/genfile/bgen/IndexQuery.hpp:16,
#                  from ../apps/bgenix.cpp:23:
# ../apps/bgenix.cpp: In member function ‘std::pair<long unsigned int, std::__cxx11::basic_string<char> > IndexBgenApplication::compute_vcf_encoding_table(int) const’:
# ../apps/bgenix.cpp:952:26: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      assert( value.size() == valueSize ) ;
#              ~~~~~~~~~~~~~^~~~
# In file included from ../apps/bgenix.cpp:19:0:
# ../genfile/include/genfile/bgen/bgen.hpp: In instantiation of ‘void genfile::bgen::v12::parse_probability_data_general(const genfile::bgen::v12::GenotypeDataBlock&, BitParser, const genfile::bgen::Context&, Setter&) [with Setter = IndexBgenApplication::VCFProbWriter; BitParser = genfile::bgen::v12::impl::SpecialisedBitParser<8>]’:
# ../genfile/include/genfile/bgen/bgen.hpp:1099:38:   required from ‘void genfile::bgen::v12::parse_probability_data(const genfile::bgen::v12::GenotypeDataBlock&, Setter&) [with Setter = IndexBgenApplication::VCFProbWriter]’
# ../apps/bgenix.cpp:864:64:   required from here
# ../genfile/include/genfile/bgen/bgen.hpp:1265:42: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for( uint32_t allele = 0; allele < (pack.numberOfAlleles-1); ++allele ) {
#                                    ~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~
# ../genfile/include/genfile/bgen/bgen.hpp: In instantiation of ‘void genfile::bgen::v12::parse_probability_data_general(const genfile::bgen::v12::GenotypeDataBlock&, BitParser, const genfile::bgen::Context&, Setter&) [with Setter = IndexBgenApplication::VCFProbWriter; BitParser = genfile::bgen::v12::impl::SpecialisedBitParser<16>]’:
# ../genfile/include/genfile/bgen/bgen.hpp:1107:38:   required from ‘void genfile::bgen::v12::parse_probability_data(const genfile::bgen::v12::GenotypeDataBlock&, Setter&) [with Setter = IndexBgenApplication::VCFProbWriter]’
# ../apps/bgenix.cpp:864:64:   required from here
# ../genfile/include/genfile/bgen/bgen.hpp:1265:42: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# ../genfile/include/genfile/bgen/bgen.hpp: In instantiation of ‘void genfile::bgen::v12::parse_probability_data_general(const genfile::bgen::v12::GenotypeDataBlock&, BitParser, const genfile::bgen::Context&, Setter&) [with Setter = IndexBgenApplication::VCFProbWriter; BitParser = genfile::bgen::v12::impl::BitParser]’:
# ../genfile/include/genfile/bgen/bgen.hpp:1115:38:   required from ‘void genfile::bgen::v12::parse_probability_data(const genfile::bgen::v12::GenotypeDataBlock&, Setter&) [with Setter = IndexBgenApplication::VCFProbWriter]’
# ../apps/bgenix.cpp:864:64:   required from here
# ../genfile/include/genfile/bgen/bgen.hpp:1265:42: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# In file included from ../3rd_party/boost_1_55_0/boost/function/detail/maybe_include.hpp:23:0,
#                  from ../3rd_party/boost_1_55_0/boost/function/detail/function_iterate.hpp:14,
#                  from ../3rd_party/boost_1_55_0/boost/preprocessor/iteration/detail/iter/forward1.hpp:57,
#                  from ../3rd_party/boost_1_55_0/boost/function.hpp:64,
#                  from ../appcontext/include/appcontext/OptionProcessor.hpp:20,
#                  from ../appcontext/include/appcontext/CmdLineOptionProcessor.hpp:15,
#                  from ../apps/bgenix.cpp:16:
# ../3rd_party/boost_1_55_0/boost/function/function_template.hpp: In instantiation of ‘void boost::detail::function::basic_vtable2<R, T0, T1>::assign_functor(FunctionObj, boost::detail::function::function_buffer&, mpl_::true_) const [with FunctionObj = appcontext::ProgressContextProxy; R = void; T0 = long unsigned int; T1 = boost::optional<long unsigned int>; mpl_::true_ = mpl_::bool_<true>]’:
# ../3rd_party/boost_1_55_0/boost/function/function_template.hpp:602:27:   required from ‘bool boost::detail::function::basic_vtable2<R, T0, T1>::assign_to(FunctionObj, boost::detail::function::function_buffer&, boost::detail::function::function_obj_tag) const [with FunctionObj = appcontext::ProgressContextProxy; R = void; T0 = long unsigned int; T1 = boost::optional<long unsigned int>]’
# ../3rd_party/boost_1_55_0/boost/function/function_template.hpp:492:27:   required from ‘bool boost::detail::function::basic_vtable2<R, T0, T1>::assign_to(F, boost::detail::function::function_buffer&) const [with F = appcontext::ProgressContextProxy; R = void; T0 = long unsigned int; T1 = boost::optional<long unsigned int>]’
# ../3rd_party/boost_1_55_0/boost/function/function_template.hpp:936:7:   required from ‘void boost::function2<R, T1, T2>::assign_to(Functor) [with Functor = appcontext::ProgressContextProxy; R = void; T0 = long unsigned int; T1 = boost::optional<long unsigned int>]’
# ../3rd_party/boost_1_55_0/boost/function/function_template.hpp:722:7:   required from ‘boost::function2<R, T1, T2>::function2(Functor, typename boost::enable_if_c<boost::type_traits::ice_not<boost::is_integral<Functor>::value>::value, int>::type) [with Functor = appcontext::ProgressContextProxy; R = void; T0 = long unsigned int; T1 = boost::optional<long unsigned int>; typename boost::enable_if_c<boost::type_traits::ice_not<boost::is_integral<Functor>::value>::value, int>::type = int]’
# ../3rd_party/boost_1_55_0/boost/function/function_template.hpp:1069:16:   required from ‘boost::function<R(T0, T1)>::function(Functor, typename boost::enable_if_c<boost::type_traits::ice_not<boost::is_integral<Functor>::value>::value, int>::type) [with Functor = appcontext::ProgressContextProxy; R = void; T0 = long unsigned int; T1 = boost::optional<long unsigned int>; typename boost::enable_if_c<boost::type_traits::ice_not<boost::is_integral<Functor>::value>::value, int>::type = int]’
# ../apps/bgenix.cpp:474:40:   required from here
# ../3rd_party/boost_1_55_0/boost/function/function_template.hpp:566:11: warning: placement new constructing an object of type ‘appcontext::ProgressContextProxy’ and size ‘16’ in a region of type ‘char’ and size ‘1’ [-Wplacement-new=]
#            new (reinterpret_cast<void*>(&functor.data)) FunctionObj(f);
#            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from ../3rd_party/boost_1_55_0/boost/function/detail/prologue.hpp:17:0,
#                  from ../3rd_party/boost_1_55_0/boost/function.hpp:24,
#                  from ../appcontext/include/appcontext/OptionProcessor.hpp:20,
#                  from ../appcontext/include/appcontext/CmdLineOptionProcessor.hpp:15,
#                  from ../apps/bgenix.cpp:16:
# ../3rd_party/boost_1_55_0/boost/function/function_base.hpp: In instantiation of ‘static void boost::detail::function::functor_manager_common<Functor>::manage_small(const boost::detail::function::function_buffer&, boost::detail::function::function_buffer&, boost::detail::function::functor_manager_operation_type) [with Functor = appcontext::ProgressContextProxy]’:
# ../3rd_party/boost_1_55_0/boost/function/function_base.hpp:364:56:   required from ‘static void boost::detail::function::functor_manager<Functor>::manager(const boost::detail::function::function_buffer&, boost::detail::function::function_buffer&, boost::detail::function::functor_manager_operation_type, mpl_::true_) [with Functor = appcontext::ProgressContextProxy; mpl_::true_ = mpl_::bool_<true>]’
# ../3rd_party/boost_1_55_0/boost/function/function_base.hpp:412:18:   required from ‘static void boost::detail::function::functor_manager<Functor>::manager(const boost::detail::function::function_buffer&, boost::detail::function::function_buffer&, boost::detail::function::functor_manager_operation_type, boost::detail::function::function_obj_tag) [with Functor = appcontext::ProgressContextProxy]’
# ../3rd_party/boost_1_55_0/boost/function/function_base.hpp:440:20:   required from ‘static void boost::detail::function::functor_manager<Functor>::manage(const boost::detail::function::function_buffer&, boost::detail::function::function_buffer&, boost::detail::function::functor_manager_operation_type) [with Functor = appcontext::ProgressContextProxy]’
# ../3rd_party/boost_1_55_0/boost/function/function_template.hpp:934:13:   required from ‘void boost::function2<R, T1, T2>::assign_to(Functor) [with Functor = appcontext::ProgressContextProxy; R = void; T0 = long unsigned int; T1 = boost::optional<long unsigned int>]’
# ../3rd_party/boost_1_55_0/boost/function/function_template.hpp:722:7:   required from ‘boost::function2<R, T1, T2>::function2(Functor, typename boost::enable_if_c<boost::type_traits::ice_not<boost::is_integral<Functor>::value>::value, int>::type) [with Functor = appcontext::ProgressContextProxy; R = void; T0 = long unsigned int; T1 = boost::optional<long unsigned int>; typename boost::enable_if_c<boost::type_traits::ice_not<boost::is_integral<Functor>::value>::value, int>::type = int]’
# ../3rd_party/boost_1_55_0/boost/function/function_template.hpp:1069:16:   required from ‘boost::function<R(T0, T1)>::function(Functor, typename boost::enable_if_c<boost::type_traits::ice_not<boost::is_integral<Functor>::value>::value, int>::type) [with Functor = appcontext::ProgressContextProxy; R = void; T0 = long unsigned int; T1 = boost::optional<long unsigned int>; typename boost::enable_if_c<boost::type_traits::ice_not<boost::is_integral<Functor>::value>::value, int>::type = int]’
# ../apps/bgenix.cpp:474:40:   required from here
# ../3rd_party/boost_1_55_0/boost/function/function_base.hpp:318:13: warning: placement new constructing an object of type ‘boost::detail::function::functor_manager_common<appcontext::ProgressContextProxy>::functor_type {aka appcontext::ProgressContextProxy}’ and size ‘16’ in a region of type ‘char’ and size ‘1’ [-Wplacement-new=]
#              new (reinterpret_cast<void*>(&out_buffer.data)) functor_type(*in_functor);
#              ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# At global scope:
# cc1plus: warning: unrecognized command line option ‘-Wno-c++11-long-long’
#
# [85/85] Linking build/apps/bgenix
# Waf: Leaving directory `/opt/notebooks/bgen.tgz/build'
# 'build' finished successfully (32.120s)
# test_header_block_input
# test_header_block_output
# test_round_probs
# test_snp_block_input_v10
# test_snp_block_input_v11
# test_snp_block_output_unphased_v11
# test_snp_block_input_unphased_v12
# test_snp_block_output_unphased_v12
# test_snp_block_input_phased_v12
# test_snp_block_output_phased_v12
# test_little_endian_integer_io
# test_probability_bound
# Sample 0, value 0 is 1.0004882812500004, expected within bounds 0 - 1.0004882812500002.
# These 3 values sum to 1.00146484375000133, I expected the sum to be in the range 0.99853515624999933 - 1.00146484375000067.
# Values are:
# 0.50048828125000133
# 0.25048828125000000
# 0.25048828125000000
# These 3 values sum to 0.99853515624999867, I expected the sum to be in the range 0.99853515624999933 - 1.00146484375000067.
# Values are:
# 0.49951171874999867
# 0.24951171875000000
# 0.24951171875000000
# Sample 0, value 1 is 1.00048828125000044, expected within bounds 0 - 1.00048828125000022.
# These 3 values sum to 1.00146484375000133, I expected the sum to be in the range 0.99853515624999933 - 1.00146484375000067.
# Values are:
# 0.25048828125000000
# 0.50048828125000133
# 0.25048828125000000
# These 3 values sum to 0.99853515624999867, I expected the sum to be in the range 0.99853515624999933 - 1.00146484375000067.
# Values are:
# 0.24951171875000000
# 0.49951171874999867
# 0.24951171875000000
# Sample 0, value 2 is 1.00048828125000044, expected within bounds 0 - 1.00048828125000022.
# These 3 values sum to 1.00146484375000133, I expected the sum to be in the range 0.99853515624999933 - 1.00146484375000067.
# Values are:
# 0.25048828125000000
# 0.25048828125000000
# 0.50048828125000133
# These 3 values sum to 0.99853515624999867, I expected the sum to be in the range 0.99853515624999933 - 1.00146484375000067.
# Values are:
# 0.24951171875000000
# 0.24951171875000000
# 0.49951171874999867
# Sample 0, value 0 is 1.00097656250000044, expected within bounds 0 - 1.00097656250000022.
# These 3 values sum to 1.00292968750000133, I expected the sum to be in the range 0.99707031249999933 - 1.00292968750000067.
# Values are:
# 0.50097656250000133
# 0.25097656250000000
# 0.25097656250000000
# These 3 values sum to 0.99707031249999867, I expected the sum to be in the range 0.99707031249999933 - 1.00292968750000067.
# Values are:
# 0.49902343749999867
# 0.24902343750000000
# 0.24902343750000000
# Sample 0, value 1 is 1.00097656250000044, expected within bounds 0 - 1.00097656250000022.
# These 3 values sum to 1.00292968750000133, I expected the sum to be in the range 0.99707031249999933 - 1.00292968750000067.
# Values are:
# 0.25097656250000000
# 0.50097656250000133
# 0.25097656250000000
# These 3 values sum to 0.99707031249999867, I expected the sum to be in the range 0.99707031249999933 - 1.00292968750000067.
# Values are:
# 0.24902343750000000
# 0.49902343749999867
# 0.24902343750000000
# Sample 0, value 2 is 1.00097656250000044, expected within bounds 0 - 1.00097656250000022.
# These 3 values sum to 1.00292968750000133, I expected the sum to be in the range 0.99707031249999933 - 1.00292968750000067.
# Values are:
# 0.25097656250000000
# 0.25097656250000000
# 0.50097656250000133
# These 3 values sum to 0.99707031249999867, I expected the sum to be in the range 0.99707031249999933 - 1.00292968750000067.
# Values are:
# 0.24902343750000000
# 0.24902343750000000
# 0.49902343749999867
# Sample 0, value 0 is 1.00050000000000039, expected within bounds 0 - 1.00050000000000017.
# These 3 values sum to 1.00150000000000117, I expected the sum to be in the range 0.99849999999999939 - 1.00150000000000072.
# Values are:
# 0.50050000000000128
# 0.25050000000000000
# 0.25050000000000000
# These 3 values sum to 0.99849999999999861, I expected the sum to be in the range 0.99849999999999939 - 1.00150000000000072.
# Values are:
# 0.49949999999999867
# 0.24950000000000000
# 0.24950000000000000
# Sample 0, value 1 is 1.00050000000000039, expected within bounds 0 - 1.00050000000000017.
# These 3 values sum to 1.00150000000000117, I expected the sum to be in the range 0.99849999999999939 - 1.00150000000000072.
# Values are:
# 0.25050000000000000
# 0.50050000000000128
# 0.25050000000000000
# These 3 values sum to 0.99849999999999861, I expected the sum to be in the range 0.99849999999999939 - 1.00150000000000072.
# Values are:
# 0.24950000000000000
# 0.49949999999999867
# 0.24950000000000000
# Sample 0, value 2 is 1.00050000000000039, expected within bounds 0 - 1.00050000000000017.
# These 3 values sum to 1.00150000000000139, I expected the sum to be in the range 0.99849999999999939 - 1.00150000000000072.
# Values are:
# 0.25050000000000000
# 0.25050000000000000
# 0.50050000000000128
# These 3 values sum to 0.99849999999999861, I expected the sum to be in the range 0.99849999999999939 - 1.00150000000000072.
# Values are:
# 0.24950000000000000
# 0.24950000000000000
# 0.49949999999999867
# Sample 0, value 0 is 1.00500000000000034, expected within bounds 0 - 1.00500000000000012.
# These 3 values sum to 1.01500000000000146, I expected the sum to be in the range 0.98499999999999932 - 1.01500000000000057.
# Values are:
# 0.50500000000000134
# 0.25500000000000000
# 0.25500000000000000
# These 3 values sum to 0.98499999999999865, I expected the sum to be in the range 0.98499999999999932 - 1.01500000000000057.
# Values are:
# 0.49499999999999866
# 0.24500000000000000
# 0.24500000000000000
# Sample 0, value 1 is 1.00500000000000034, expected within bounds 0 - 1.00500000000000012.
# These 3 values sum to 1.01500000000000146, I expected the sum to be in the range 0.98499999999999932 - 1.01500000000000057.
# Values are:
# 0.25500000000000000
# 0.50500000000000134
# 0.25500000000000000
# These 3 values sum to 0.98499999999999865, I expected the sum to be in the range 0.98499999999999932 - 1.01500000000000057.
# Values are:
# 0.24500000000000000
# 0.49499999999999866
# 0.24500000000000000
# Sample 0, value 2 is 1.00500000000000034, expected within bounds 0 - 1.00500000000000012.
# These 3 values sum to 1.01500000000000146, I expected the sum to be in the range 0.98499999999999932 - 1.01500000000000057.
# Values are:
# 0.25500000000000000
# 0.25500000000000000
# 0.50500000000000134
# These 3 values sum to 0.98499999999999865, I expected the sum to be in the range 0.98499999999999932 - 1.01500000000000057.
# Values are:
# 0.24500000000000000
# 0.24500000000000000
# 0.49499999999999866
# Sample 0, value 0 is 1.02000000000000046, expected within bounds 0 - 1.02000000000000024.
# These 3 values sum to 1.06000000000000139, I expected the sum to be in the range 0.93999999999999928 - 1.06000000000000072.
# Values are:
# 0.52000000000000135
# 0.27000000000000002
# 0.27000000000000002
# These 3 values sum to 0.93999999999999861, I expected the sum to be in the range 0.93999999999999928 - 1.06000000000000072.
# Values are:
# 0.47999999999999865
# 0.23000000000000001
# 0.23000000000000001
# Sample 0, value 1 is 1.02000000000000046, expected within bounds 0 - 1.02000000000000024.
# These 3 values sum to 1.06000000000000139, I expected the sum to be in the range 0.93999999999999928 - 1.06000000000000072.
# Values are:
# 0.27000000000000002
# 0.52000000000000135
# 0.27000000000000002
# These 3 values sum to 0.93999999999999861, I expected the sum to be in the range 0.93999999999999928 - 1.06000000000000072.
# Values are:
# 0.23000000000000001
# 0.47999999999999865
# 0.23000000000000001
# Sample 0, value 2 is 1.02000000000000046, expected within bounds 0 - 1.02000000000000024.
# These 3 values sum to 1.06000000000000139, I expected the sum to be in the range 0.93999999999999928 - 1.06000000000000072.
# Values are:
# 0.27000000000000002
# 0.27000000000000002
# 0.52000000000000135
# These 3 values sum to 0.93999999999999861, I expected the sum to be in the range 0.93999999999999928 - 1.06000000000000072.
# Values are:
# 0.23000000000000001
# 0.23000000000000001
# 0.47999999999999865
# Sample 0, value 0 is 1.05000000000000049, expected within bounds 0 - 1.05000000000000027.
# These 3 values sum to 1.15000000000000147, I expected the sum to be in the range 0.84999999999999931 - 1.15000000000000080.
# Values are:
# 0.55000000000000138
# 0.29999999999999999
# 0.29999999999999999
# These 3 values sum to 0.84999999999999876, I expected the sum to be in the range 0.84999999999999931 - 1.15000000000000080.
# Values are:
# 0.44999999999999868
# 0.20000000000000001
# 0.20000000000000001
# Sample 0, value 1 is 1.05000000000000049, expected within bounds 0 - 1.05000000000000027.
# These 3 values sum to 1.15000000000000147, I expected the sum to be in the range 0.84999999999999931 - 1.15000000000000080.
# Values are:
# 0.29999999999999999
# 0.55000000000000138
# 0.29999999999999999
# These 3 values sum to 0.84999999999999876, I expected the sum to be in the range 0.84999999999999931 - 1.15000000000000080.
# Values are:
# 0.20000000000000001
# 0.44999999999999868
# 0.20000000000000001
# Sample 0, value 2 is 1.05000000000000049, expected within bounds 0 - 1.05000000000000027.
# These 3 values sum to 1.15000000000000124, I expected the sum to be in the range 0.84999999999999931 - 1.15000000000000080.
# Values are:
# 0.29999999999999999
# 0.29999999999999999
# 0.55000000000000138
# These 3 values sum to 0.84999999999999876, I expected the sum to be in the range 0.84999999999999931 - 1.15000000000000080.
# Values are:
# 0.20000000000000001
# 0.20000000000000001
# 0.44999999999999868
# test_single_sample_biallelic_unphased
# test_single_sample_biallelic_phased
# test_two_samples
# test_truncated
# ===============================================================================
# All tests passed (1950006 assertions in 16 test cases)
#
# !! Error (OptionProcessingException): The following options were not recognised: –list..
# Please consult the documentation, or use "bgenix -help" for more information.

# %% [markdown]
# ## download and install PLINK2
# ### see https://www.cog-genomics.org/plink/2.0/
# ### WARNING: the download link may have to be updated

# %%
cd /opt/notebooks
wget https://s3.amazonaws.com/plink2-assets/alpha3/plink2_linux_avx2_20220814.zip
unzip -o plink2_linux_avx2_20220814.zip
./plink2 --version
# Out:
# --2022-09-27 07:27:02--  https://s3.amazonaws.com/plink2-assets/alpha3/plink2_linux_avx2_20220814.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 54.231.170.160
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|54.231.170.160|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9134949 (8.7M) [application/zip]
# Saving to: ‘plink2_linux_avx2_20220814.zip’
#
# plink2_linux_avx2_2 100%[===================>]   8.71M  14.1MB/s    in 0.6s
#
# 2022-09-27 07:27:03 (14.1 MB/s) - ‘plink2_linux_avx2_20220814.zip’ saved [9134949/9134949]
#
# Archive:  plink2_linux_avx2_20220814.zip
#   inflating: plink2
# PLINK v2.00a3.6LM AVX2 Intel (14 Aug 2022)

# %% [markdown]
# ## Create shortcuts to genotype directories (i.e. to avoid problems with Jupyter using blanks in file names)

# %%
DIR=/mnt/project/Bulk/Imputation/UKB*imputation*from*genotype/
ln -sf $DIR /opt/notebooks/impu

DIR=/mnt/project/Bulk/Genotype*Results/Genotype*calls/
ln -sf $DIR /opt/notebooks/geno

# define a function to extract genotyped SNPs [not really needed, just to keep the syntax, we use imputed SNPs below]
function extract_SNP () {
  SNP=${1-rs174547}
  CHR=${2-11}
  echo "extracting SNP $SNP on chromosome $CHR"
  ./plink2 --bfile  geno/ukb22418_c${CHR}_b0_v2 --snp $SNP --export  A  'include-alt' --out ${SNP}
  # head -5 ${SNP}.raw
}
## test the function on a single SNP
extract_SNP rs780094 2
# Out:
# extracting SNP rs780094 on chromosome 2
# PLINK v2.00a3.6LM AVX2 Intel (14 Aug 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to rs780094.log.
# Options in effect:
#   --bfile geno/ukb22418_c2_b0_v2
#   --export A include-alt
#   --out rs780094
#   --snp rs780094
#
# Start time: Tue Sep 27 07:27:06 2022
# 7605 MiB RAM detected; reserving 3802 MiB for main workspace.
# Using up to 4 compute threads.
# 488377 samples (264746 females, 223430 males, 201 ambiguous; 488377 founders)
# loaded from geno/ukb22418_c2_b0_v2.fam.
# 61966 variants loaded from geno/ukb22418_c2_b0_v2.bim.
# 1 categorical phenotype loaded (488377 values).
# --snp: 1 variant remaining.
# 1 variant remaining after main filters.
# --export A pass 1/1: loading... 0writing... .
# --export A: rs780094.raw written.
# End time: Tue Sep 27 07:27:11 2022

# %% [markdown]
# # Create a list of SNPs to retrieve
#
# SNPs need to be in the format CHR:POS1-POS2
# where individual SNPs are indicated by identical from - to positions
# (note that single digit chromosomes need to be indicated using a leading zero)

# %%
# crreate a list of SNPs to retrieve 
cat > mypos.txt <<EOF
01:914852-914852
01:2147162-2147162
01:2326009-2326009
22:50746706-50746706
22:50840573-50840573
22:50858813-50858813
EOF

# %% [markdown]
# # extract SNPs by position

# %%
# genotype data is stored by chromosome, so we loop over these files
CFROM=1
CTO=22

export CHR=$CFROM
while [ $CHR -le $CTO ] ; do

  echo "working on CHR $CHR"
  
  # extract from one BGEN file
  /opt/notebooks/bgen.tgz/build/apps/bgenix -g impu/ukb22828_c${CHR}_b0_v3.bgen -incl-range mypos.txt > mypos.${CHR}.bgen

  # convert to text using PLINK
  ./plink2 --bgen mypos.${CHR}.bgen ref-first --sample impu/ukb22828_c${CHR}_b0_v3.sample --export  A  'include-alt' --out mypos.${CHR} --make-bed
  # head -5 mypos.${CHR}.raw
  wc -l mypos.${CHR}.raw

  ls -ltr mypos.${CHR}*

  ((CHR=CHR+1))
  
done
# Out:
# working on CHR 1
#
# Welcome to bgenix
# (version: 1.1.7, revision )
#
# (C) 2009-2017 University of Oxford
#
# Building query                                              :  (3/?,0.6s,4.8/s)
# Processing 3 variants                                       : [******************************] (3/3,0.7s,4.2/s)
# bgenix: wrote data for 3 variants to stdout.
#
# Thank you for using bgenix.
# PLINK v2.00a3.6LM AVX2 Intel (14 Aug 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to mypos.1.log.
# Options in effect:
#   --bgen mypos.1.bgen ref-first
#   --export A include-alt
#   --make-bed
#   --out mypos.1
#   --sample impu/ukb22828_c1_b0_v3.sample
#
# Start time: Tue Sep 27 07:27:19 2022
# 7605 MiB RAM detected; reserving 3802 MiB for main workspace.
# Using up to 4 compute threads.
# --bgen: 3 variants detected, format v1.2.
# 487409 samples imported from .sample file to mypos.1-temporary.psam .
# --bgen: mypos.1-temporary.pgen + mypos.1-temporary.pvar written.
# 487409 samples (264251 females, 222957 males, 201 ambiguous; 487409 founders)
# loaded from mypos.1-temporary.psam.
# 3 variants loaded from mypos.1-temporary.pvar.
# Note: No phenotype data present.
# Writing mypos.1.fam ... done.
# Writing mypos.1.bim ... done.
# Writing mypos.1.bed ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: mypos.1.raw written.
# End time: Tue Sep 27 07:27:20 2022
# 487410 mypos.1.raw
# -rw-r--r-- 1 root root 16258832 Sep 27 07:27 mypos.1.bgen
# -rw-r--r-- 1 root root 12183803 Sep 27 07:27 mypos.1.fam
# -rw-r--r-- 1 root root       78 Sep 27 07:27 mypos.1.bim
# -rw-r--r-- 1 root root   365562 Sep 27 07:27 mypos.1.bed
# -rw-r--r-- 1 root root 15763198 Sep 27 07:27 mypos.1.raw
# -rw-r--r-- 1 root root      939 Sep 27 07:27 mypos.1.log
# working on CHR 2
#
# Welcome to bgenix
# (version: 1.1.7, revision )
#
# (C) 2009-2017 University of Oxford
#
# Building query                                              :  (0/?,0.6s,0.0/s)
# Processing 0 variants                                       :  (0/?,0.0s,0.0/s)
# bgenix: wrote data for 0 variants to stdout.
#
# Thank you for using bgenix.
# PLINK v2.00a3.6LM AVX2 Intel (14 Aug 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to mypos.2.log.
# Options in effect:
#   --bgen mypos.2.bgen ref-first
#   --export A include-alt
#   --make-bed
#   --out mypos.2
#   --sample impu/ukb22828_c2_b0_v3.sample
#
# Start time: Tue Sep 27 07:27:25 2022
# 7605 MiB RAM detected; reserving 3802 MiB for main workspace.
# Using up to 4 compute threads.
# Error: Empty .bgen file.
# End time: Tue Sep 27 07:27:25 2022
# wc: mypos.2.raw: No such file or directory
# -rw-r--r-- 1 root root 15609040 Sep 27 07:27 mypos.2.bgen
# -rw-r--r-- 1 root root      470 Sep 27 07:27 mypos.2.log
# working on CHR 3
#
# Welcome to bgenix
# (version: 1.1.7, revision )
#
# (C) 2009-2017 University of Oxford
#
# Building query                                              :  (0/?,0.5s,0.0/s)
# Processing 0 variants                                       :  (0/?,0.0s,0.0/s)
# bgenix: wrote data for 0 variants to stdout.
#
# Thank you for using bgenix.
# PLINK v2.00a3.6LM AVX2 Intel (14 Aug 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to mypos.3.log.
# Options in effect:
#   --bgen mypos.3.bgen ref-first
#   --export A include-alt
#   --make-bed
#   --out mypos.3
#   --sample impu/ukb22828_c3_b0_v3.sample
#
# Start time: Tue Sep 27 07:27:29 2022
# 7605 MiB RAM detected; reserving 3802 MiB for main workspace.
# Using up to 4 compute threads.
# Error: Empty .bgen file.
# End time: Tue Sep 27 07:27:29 2022
# wc: mypos.3.raw: No such file or directory
# -rw-r--r-- 1 root root 15609040 Sep 27 07:27 mypos.3.bgen
# -rw-r--r-- 1 root root      470 Sep 27 07:27 mypos.3.log
# working on CHR 4
#
# Welcome to bgenix
# (version: 1.1.7, revision )
#
# (C) 2009-2017 University of Oxford
#
# Building query                                              :  (0/?,0.5s,0.0/s)
# Processing 0 variants                                       :  (0/?,0.0s,0.0/s)
# bgenix: wrote data for 0 variants to stdout.
#
# Thank you for using bgenix.
# PLINK v2.00a3.6LM AVX2 Intel (14 Aug 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to mypos.4.log.
# Options in effect:
#   --bgen mypos.4.bgen ref-first
#   --export A include-alt
#   --make-bed
#   --out mypos.4
#   --sample impu/ukb22828_c4_b0_v3.sample
#
# Start time: Tue Sep 27 07:27:33 2022
# 7605 MiB RAM detected; reserving 3802 MiB for main workspace.
# Using up to 4 compute threads.
# Error: Empty .bgen file.
# End time: Tue Sep 27 07:27:33 2022
# wc: mypos.4.raw: No such file or directory
# -rw-r--r-- 1 root root 15609040 Sep 27 07:27 mypos.4.bgen
# -rw-r--r-- 1 root root      470 Sep 27 07:27 mypos.4.log
# working on CHR 5
#
# Welcome to bgenix
# (version: 1.1.7, revision )
#
# (C) 2009-2017 University of Oxford
#
# Building query                                              :  (0/?,0.5s,0.0/s)
# Processing 0 variants                                       :  (0/?,0.0s,0.0/s)
# bgenix: wrote data for 0 variants to stdout.
#
# Thank you for using bgenix.
# PLINK v2.00a3.6LM AVX2 Intel (14 Aug 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to mypos.5.log.
# Options in effect:
#   --bgen mypos.5.bgen ref-first
#   --export A include-alt
#   --make-bed
#   --out mypos.5
#   --sample impu/ukb22828_c5_b0_v3.sample
#
# Start time: Tue Sep 27 07:27:38 2022
# 7605 MiB RAM detected; reserving 3802 MiB for main workspace.
# Using up to 4 compute threads.
# Error: Empty .bgen file.
# End time: Tue Sep 27 07:27:38 2022
# wc: mypos.5.raw: No such file or directory
# -rw-r--r-- 1 root root 15609040 Sep 27 07:27 mypos.5.bgen
# -rw-r--r-- 1 root root      470 Sep 27 07:27 mypos.5.log
# working on CHR 6
#
# Welcome to bgenix
# (version: 1.1.7, revision )
#
# (C) 2009-2017 University of Oxford
#
# Building query                                              :  (0/?,0.6s,0.0/s)
# Processing 0 variants                                       :  (0/?,0.0s,0.0/s)
# bgenix: wrote data for 0 variants to stdout.
#
# Thank you for using bgenix.
# PLINK v2.00a3.6LM AVX2 Intel (14 Aug 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to mypos.6.log.
# Options in effect:
#   --bgen mypos.6.bgen ref-first
#   --export A include-alt
#   --make-bed
#   --out mypos.6
#   --sample impu/ukb22828_c6_b0_v3.sample
#
# Start time: Tue Sep 27 07:27:43 2022
# 7605 MiB RAM detected; reserving 3802 MiB for main workspace.
# Using up to 4 compute threads.
# Error: Empty .bgen file.
# End time: Tue Sep 27 07:27:43 2022
# wc: mypos.6.raw: No such file or directory
# -rw-r--r-- 1 root root 15609040 Sep 27 07:27 mypos.6.bgen
# -rw-r--r-- 1 root root      470 Sep 27 07:27 mypos.6.log
# working on CHR 7
#
# Welcome to bgenix
# (version: 1.1.7, revision )
#
# (C) 2009-2017 University of Oxford
#
# Building query                                              :  (0/?,0.6s,0.0/s)
# Processing 0 variants                                       :  (0/?,0.0s,0.0/s)
# bgenix: wrote data for 0 variants to stdout.
#
# Thank you for using bgenix.
# PLINK v2.00a3.6LM AVX2 Intel (14 Aug 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to mypos.7.log.
# Options in effect:
#   --bgen mypos.7.bgen ref-first
#   --export A include-alt
#   --make-bed
#   --out mypos.7
#   --sample impu/ukb22828_c7_b0_v3.sample
#
# Start time: Tue Sep 27 07:27:47 2022
# 7605 MiB RAM detected; reserving 3802 MiB for main workspace.
# Using up to 4 compute threads.
# Error: Empty .bgen file.
# End time: Tue Sep 27 07:27:47 2022
# wc: mypos.7.raw: No such file or directory
# -rw-r--r-- 1 root root 15609040 Sep 27 07:27 mypos.7.bgen
# -rw-r--r-- 1 root root      470 Sep 27 07:27 mypos.7.log
# working on CHR 8
#
# Welcome to bgenix
# (version: 1.1.7, revision )
#
# (C) 2009-2017 University of Oxford
#
# Building query                                              :  (0/?,0.4s,0.0/s)
# Processing 0 variants                                       :  (0/?,0.0s,0.0/s)
# bgenix: wrote data for 0 variants to stdout.
#
# Thank you for using bgenix.
# PLINK v2.00a3.6LM AVX2 Intel (14 Aug 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to mypos.8.log.
# Options in effect:
#   --bgen mypos.8.bgen ref-first
#   --export A include-alt
#   --make-bed
#   --out mypos.8
#   --sample impu/ukb22828_c8_b0_v3.sample
#
# Start time: Tue Sep 27 07:27:51 2022
# 7605 MiB RAM detected; reserving 3802 MiB for main workspace.
# Using up to 4 compute threads.
# Error: Empty .bgen file.
# End time: Tue Sep 27 07:27:51 2022
# wc: mypos.8.raw: No such file or directory
# -rw-r--r-- 1 root root 15609040 Sep 27 07:27 mypos.8.bgen
# -rw-r--r-- 1 root root      470 Sep 27 07:27 mypos.8.log
# working on CHR 9
#
# Welcome to bgenix
# (version: 1.1.7, revision )
#
# (C) 2009-2017 University of Oxford
#
# Building query                                              :  (0/?,0.5s,0.0/s)
# Processing 0 variants                                       :  (0/?,0.0s,0.0/s)
# bgenix: wrote data for 0 variants to stdout.
#
# Thank you for using bgenix.
# PLINK v2.00a3.6LM AVX2 Intel (14 Aug 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to mypos.9.log.
# Options in effect:
#   --bgen mypos.9.bgen ref-first
#   --export A include-alt
#   --make-bed
#   --out mypos.9
#   --sample impu/ukb22828_c9_b0_v3.sample
#
# Start time: Tue Sep 27 07:27:56 2022
# 7605 MiB RAM detected; reserving 3802 MiB for main workspace.
# Using up to 4 compute threads.
# Error: Empty .bgen file.
# End time: Tue Sep 27 07:27:56 2022
# wc: mypos.9.raw: No such file or directory
# -rw-r--r-- 1 root root 15609040 Sep 27 07:27 mypos.9.bgen
# -rw-r--r-- 1 root root      470 Sep 27 07:27 mypos.9.log
# working on CHR 10
#
# Welcome to bgenix
# (version: 1.1.7, revision )
#
# (C) 2009-2017 University of Oxford
#
# Building query                                              :  (0/?,0.5s,0.0/s)
# Processing 0 variants                                       :  (0/?,0.0s,0.0/s)
# bgenix: wrote data for 0 variants to stdout.
#
# Thank you for using bgenix.
# PLINK v2.00a3.6LM AVX2 Intel (14 Aug 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to mypos.10.log.
# Options in effect:
#   --bgen mypos.10.bgen ref-first
#   --export A include-alt
#   --make-bed
#   --out mypos.10
#   --sample impu/ukb22828_c10_b0_v3.sample
#
# Start time: Tue Sep 27 07:28:01 2022
# 7605 MiB RAM detected; reserving 3802 MiB for main workspace.
# Using up to 4 compute threads.
# Error: Empty .bgen file.
# End time: Tue Sep 27 07:28:01 2022
# wc: mypos.10.raw: No such file or directory
# -rw-r--r-- 1 root root 15609040 Sep 27 07:28 mypos.10.bgen
# -rw-r--r-- 1 root root      473 Sep 27 07:28 mypos.10.log
# working on CHR 11
#
# Welcome to bgenix
# (version: 1.1.7, revision )
#
# (C) 2009-2017 University of Oxford
#
# Building query                                              :  (0/?,0.5s,0.0/s)
# Processing 0 variants                                       :  (0/?,0.0s,0.0/s)
# bgenix: wrote data for 0 variants to stdout.
#
# Thank you for using bgenix.
# PLINK v2.00a3.6LM AVX2 Intel (14 Aug 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to mypos.11.log.
# Options in effect:
#   --bgen mypos.11.bgen ref-first
#   --export A include-alt
#   --make-bed
#   --out mypos.11
#   --sample impu/ukb22828_c11_b0_v3.sample
#
# Start time: Tue Sep 27 07:28:05 2022
# 7605 MiB RAM detected; reserving 3802 MiB for main workspace.
# Using up to 4 compute threads.
# Error: Empty .bgen file.
# End time: Tue Sep 27 07:28:05 2022
# wc: mypos.11.raw: No such file or directory
# -rw-r--r-- 1 root root 15609040 Sep 27 07:28 mypos.11.bgen
# -rw-r--r-- 1 root root      473 Sep 27 07:28 mypos.11.log
# working on CHR 12
#
# Welcome to bgenix
# (version: 1.1.7, revision )
#
# (C) 2009-2017 University of Oxford
#
# Building query                                              :  (0/?,0.5s,0.0/s)
# Processing 0 variants                                       :  (0/?,0.0s,0.0/s)
# bgenix: wrote data for 0 variants to stdout.
#
# Thank you for using bgenix.
# PLINK v2.00a3.6LM AVX2 Intel (14 Aug 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to mypos.12.log.
# Options in effect:
#   --bgen mypos.12.bgen ref-first
#   --export A include-alt
#   --make-bed
#   --out mypos.12
#   --sample impu/ukb22828_c12_b0_v3.sample
#
# Start time: Tue Sep 27 07:28:10 2022
# 7605 MiB RAM detected; reserving 3802 MiB for main workspace.
# Using up to 4 compute threads.
# Error: Empty .bgen file.
# End time: Tue Sep 27 07:28:10 2022
# wc: mypos.12.raw: No such file or directory
# -rw-r--r-- 1 root root 15609040 Sep 27 07:28 mypos.12.bgen
# -rw-r--r-- 1 root root      473 Sep 27 07:28 mypos.12.log
# working on CHR 13
#
# Welcome to bgenix
# (version: 1.1.7, revision )
#
# (C) 2009-2017 University of Oxford
#
# Building query                                              :  (0/?,0.5s,0.0/s)
# Processing 0 variants                                       :  (0/?,0.0s,0.0/s)
# bgenix: wrote data for 0 variants to stdout.
#
# Thank you for using bgenix.
# PLINK v2.00a3.6LM AVX2 Intel (14 Aug 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to mypos.13.log.
# Options in effect:
#   --bgen mypos.13.bgen ref-first
#   --export A include-alt
#   --make-bed
#   --out mypos.13
#   --sample impu/ukb22828_c13_b0_v3.sample
#
# Start time: Tue Sep 27 07:28:15 2022
# 7605 MiB RAM detected; reserving 3802 MiB for main workspace.
# Using up to 4 compute threads.
# Error: Empty .bgen file.
# End time: Tue Sep 27 07:28:15 2022
# wc: mypos.13.raw: No such file or directory
# -rw-r--r-- 1 root root 15609040 Sep 27 07:28 mypos.13.bgen
# -rw-r--r-- 1 root root      473 Sep 27 07:28 mypos.13.log
# working on CHR 14
#
# Welcome to bgenix
# (version: 1.1.7, revision )
#
# (C) 2009-2017 University of Oxford
#
# Building query                                              :  (0/?,0.5s,0.0/s)
# Processing 0 variants                                       :  (0/?,0.0s,0.0/s)
# bgenix: wrote data for 0 variants to stdout.
#
# Thank you for using bgenix.
# PLINK v2.00a3.6LM AVX2 Intel (14 Aug 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to mypos.14.log.
# Options in effect:
#   --bgen mypos.14.bgen ref-first
#   --export A include-alt
#   --make-bed
#   --out mypos.14
#   --sample impu/ukb22828_c14_b0_v3.sample
#
# Start time: Tue Sep 27 07:28:19 2022
# 7605 MiB RAM detected; reserving 3802 MiB for main workspace.
# Using up to 4 compute threads.
# Error: Empty .bgen file.
# End time: Tue Sep 27 07:28:19 2022
# wc: mypos.14.raw: No such file or directory
# -rw-r--r-- 1 root root 15609040 Sep 27 07:28 mypos.14.bgen
# -rw-r--r-- 1 root root      473 Sep 27 07:28 mypos.14.log
# working on CHR 15
#
# Welcome to bgenix
# (version: 1.1.7, revision )
#
# (C) 2009-2017 University of Oxford
#
# Building query                                              :  (0/?,0.5s,0.0/s)
# Processing 0 variants                                       :  (0/?,0.0s,0.0/s)
# bgenix: wrote data for 0 variants to stdout.
#
# Thank you for using bgenix.
# PLINK v2.00a3.6LM AVX2 Intel (14 Aug 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to mypos.15.log.
# Options in effect:
#   --bgen mypos.15.bgen ref-first
#   --export A include-alt
#   --make-bed
#   --out mypos.15
#   --sample impu/ukb22828_c15_b0_v3.sample
#
# Start time: Tue Sep 27 07:28:24 2022
# 7605 MiB RAM detected; reserving 3802 MiB for main workspace.
# Using up to 4 compute threads.
# Error: Empty .bgen file.
# End time: Tue Sep 27 07:28:24 2022
# wc: mypos.15.raw: No such file or directory
# -rw-r--r-- 1 root root 15609040 Sep 27 07:28 mypos.15.bgen
# -rw-r--r-- 1 root root      473 Sep 27 07:28 mypos.15.log
# working on CHR 16
#
# Welcome to bgenix
# (version: 1.1.7, revision )
#
# (C) 2009-2017 University of Oxford
#
# Building query                                              :  (0/?,0.5s,0.0/s)
# Processing 0 variants                                       :  (0/?,0.0s,0.0/s)
# bgenix: wrote data for 0 variants to stdout.
#
# Thank you for using bgenix.
# PLINK v2.00a3.6LM AVX2 Intel (14 Aug 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to mypos.16.log.
# Options in effect:
#   --bgen mypos.16.bgen ref-first
#   --export A include-alt
#   --make-bed
#   --out mypos.16
#   --sample impu/ukb22828_c16_b0_v3.sample
#
# Start time: Tue Sep 27 07:28:29 2022
# 7605 MiB RAM detected; reserving 3802 MiB for main workspace.
# Using up to 4 compute threads.
# Error: Empty .bgen file.
# End time: Tue Sep 27 07:28:29 2022
# wc: mypos.16.raw: No such file or directory
# -rw-r--r-- 1 root root 15609040 Sep 27 07:28 mypos.16.bgen
# -rw-r--r-- 1 root root      473 Sep 27 07:28 mypos.16.log
# working on CHR 17
#
# Welcome to bgenix
# (version: 1.1.7, revision )
#
# (C) 2009-2017 University of Oxford
#
# Building query                                              :  (0/?,0.6s,0.0/s)
# Processing 0 variants                                       :  (0/?,0.0s,0.0/s)
# bgenix: wrote data for 0 variants to stdout.
#
# Thank you for using bgenix.
# PLINK v2.00a3.6LM AVX2 Intel (14 Aug 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to mypos.17.log.
# Options in effect:
#   --bgen mypos.17.bgen ref-first
#   --export A include-alt
#   --make-bed
#   --out mypos.17
#   --sample impu/ukb22828_c17_b0_v3.sample
#
# Start time: Tue Sep 27 07:28:33 2022
# 7605 MiB RAM detected; reserving 3802 MiB for main workspace.
# Using up to 4 compute threads.
# Error: Empty .bgen file.
# End time: Tue Sep 27 07:28:33 2022
# wc: mypos.17.raw: No such file or directory
# -rw-r--r-- 1 root root 15609040 Sep 27 07:28 mypos.17.bgen
# -rw-r--r-- 1 root root      473 Sep 27 07:28 mypos.17.log
# working on CHR 18
#
# Welcome to bgenix
# (version: 1.1.7, revision )
#
# (C) 2009-2017 University of Oxford
#
# Building query                                              :  (0/?,0.4s,0.0/s)
# Processing 0 variants                                       :  (0/?,0.0s,0.0/s)
# bgenix: wrote data for 0 variants to stdout.
#
# Thank you for using bgenix.
# PLINK v2.00a3.6LM AVX2 Intel (14 Aug 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to mypos.18.log.
# Options in effect:
#   --bgen mypos.18.bgen ref-first
#   --export A include-alt
#   --make-bed
#   --out mypos.18
#   --sample impu/ukb22828_c18_b0_v3.sample
#
# Start time: Tue Sep 27 07:28:38 2022
# 7605 MiB RAM detected; reserving 3802 MiB for main workspace.
# Using up to 4 compute threads.
# Error: Empty .bgen file.
# End time: Tue Sep 27 07:28:38 2022
# wc: mypos.18.raw: No such file or directory
# -rw-r--r-- 1 root root 15609040 Sep 27 07:28 mypos.18.bgen
# -rw-r--r-- 1 root root      473 Sep 27 07:28 mypos.18.log
# working on CHR 19
#
# Welcome to bgenix
# (version: 1.1.7, revision )
#
# (C) 2009-2017 University of Oxford
#
# Building query                                              :  (0/?,0.4s,0.0/s)
# Processing 0 variants                                       :  (0/?,0.0s,0.0/s)
# bgenix: wrote data for 0 variants to stdout.
#
# Thank you for using bgenix.
# PLINK v2.00a3.6LM AVX2 Intel (14 Aug 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to mypos.19.log.
# Options in effect:
#   --bgen mypos.19.bgen ref-first
#   --export A include-alt
#   --make-bed
#   --out mypos.19
#   --sample impu/ukb22828_c19_b0_v3.sample
#
# Start time: Tue Sep 27 07:28:42 2022
# 7605 MiB RAM detected; reserving 3802 MiB for main workspace.
# Using up to 4 compute threads.
# Error: Empty .bgen file.
# End time: Tue Sep 27 07:28:42 2022
# wc: mypos.19.raw: No such file or directory
# -rw-r--r-- 1 root root 15609040 Sep 27 07:28 mypos.19.bgen
# -rw-r--r-- 1 root root      473 Sep 27 07:28 mypos.19.log
# working on CHR 20
#
# Welcome to bgenix
# (version: 1.1.7, revision )
#
# (C) 2009-2017 University of Oxford
#
# Building query                                              :  (0/?,0.6s,0.0/s)
# Processing 0 variants                                       :  (0/?,0.0s,0.0/s)
# bgenix: wrote data for 0 variants to stdout.
#
# Thank you for using bgenix.
# PLINK v2.00a3.6LM AVX2 Intel (14 Aug 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to mypos.20.log.
# Options in effect:
#   --bgen mypos.20.bgen ref-first
#   --export A include-alt
#   --make-bed
#   --out mypos.20
#   --sample impu/ukb22828_c20_b0_v3.sample
#
# Start time: Tue Sep 27 07:28:47 2022
# 7605 MiB RAM detected; reserving 3802 MiB for main workspace.
# Using up to 4 compute threads.
# Error: Empty .bgen file.
# End time: Tue Sep 27 07:28:47 2022
# wc: mypos.20.raw: No such file or directory
# -rw-r--r-- 1 root root 15609040 Sep 27 07:28 mypos.20.bgen
# -rw-r--r-- 1 root root      473 Sep 27 07:28 mypos.20.log
# working on CHR 21
#
# Welcome to bgenix
# (version: 1.1.7, revision )
#
# (C) 2009-2017 University of Oxford
#
# Building query                                              :  (0/?,0.4s,0.0/s)
# Processing 0 variants                                       :  (0/?,0.0s,0.0/s)
# bgenix: wrote data for 0 variants to stdout.
#
# Thank you for using bgenix.
# PLINK v2.00a3.6LM AVX2 Intel (14 Aug 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to mypos.21.log.
# Options in effect:
#   --bgen mypos.21.bgen ref-first
#   --export A include-alt
#   --make-bed
#   --out mypos.21
#   --sample impu/ukb22828_c21_b0_v3.sample
#
# Start time: Tue Sep 27 07:28:51 2022
# 7605 MiB RAM detected; reserving 3802 MiB for main workspace.
# Using up to 4 compute threads.
# Error: Empty .bgen file.
# End time: Tue Sep 27 07:28:51 2022
# wc: mypos.21.raw: No such file or directory
# -rw-r--r-- 1 root root 15609040 Sep 27 07:28 mypos.21.bgen
# -rw-r--r-- 1 root root      473 Sep 27 07:28 mypos.21.log
# working on CHR 22
#
# Welcome to bgenix
# (version: 1.1.7, revision )
#
# (C) 2009-2017 University of Oxford
#
# Building query                                              :  (3/?,0.5s,6.3/s)
# Processing 3 variants                                       : [******************************] (3/3,1.0s,3.2/s)
# bgenix: wrote data for 3 variants to stdout.
#
# Thank you for using bgenix.
# PLINK v2.00a3.6LM AVX2 Intel (14 Aug 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to mypos.22.log.
# Options in effect:
#   --bgen mypos.22.bgen ref-first
#   --export A include-alt
#   --make-bed
#   --out mypos.22
#   --sample impu/ukb22828_c22_b0_v3.sample
#
# Start time: Tue Sep 27 07:28:57 2022
# 7605 MiB RAM detected; reserving 3802 MiB for main workspace.
# Using up to 4 compute threads.
# --bgen: 3 variants detected, format v1.2.
# 487409 samples imported from .sample file to mypos.22-temporary.psam .
# --bgen: mypos.22-temporary.pgen + mypos.22-temporary.pvar written.
# 487409 samples (264251 females, 222957 males, 201 ambiguous; 487409 founders)
# loaded from mypos.22-temporary.psam.
# 3 variants loaded from mypos.22-temporary.pvar.
# Note: No phenotype data present.
# Writing mypos.22.fam ... done.
# Writing mypos.22.bim ... done.
# Writing mypos.22.bed ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: mypos.22.raw written.
# End time: Tue Sep 27 07:28:58 2022
# 487410 mypos.22.raw
# -rw-r--r-- 1 root root 16085082 Sep 27 07:28 mypos.22.bgen
# -rw-r--r-- 1 root root 12183803 Sep 27 07:28 mypos.22.fam
# -rw-r--r-- 1 root root       85 Sep 27 07:28 mypos.22.bim
# -rw-r--r-- 1 root root   365562 Sep 27 07:28 mypos.22.bed
# -rw-r--r-- 1 root root 15417145 Sep 27 07:28 mypos.22.raw
# -rw-r--r-- 1 root root      951 Sep 27 07:28 mypos.22.log

# %% [markdown]
# # upload to project directory

# %%
tar cvfz SNPdata.tgz mypos.*
# Out:
# mypos.1.bed
# mypos.1.bgen
# mypos.1.bim
# mypos.1.fam
# mypos.1.log
# mypos.1.raw
# mypos.10.bgen
# mypos.10.log
# mypos.11.bgen
# mypos.11.log
# mypos.12.bgen
# mypos.12.log
# mypos.13.bgen
# mypos.13.log
# mypos.14.bgen
# mypos.14.log
# mypos.15.bgen
# mypos.15.log
# mypos.16.bgen
# mypos.16.log
# mypos.17.bgen
# mypos.17.log
# mypos.18.bgen
# mypos.18.log
# mypos.19.bgen
# mypos.19.log
# mypos.2.bgen
# mypos.2.log
# mypos.20.bgen
# mypos.20.log
# mypos.21.bgen
# mypos.21.log
# mypos.22.bed
# mypos.22.bgen
# mypos.22.bim
# mypos.22.fam
# mypos.22.log
# mypos.22.raw
# mypos.3.bgen
# mypos.3.log
# mypos.4.bgen
# mypos.4.log
# mypos.5.bgen
# mypos.5.log
# mypos.6.bgen
# mypos.6.log
# mypos.7.bgen
# mypos.7.log
# mypos.8.bgen
# mypos.8.log
# mypos.9.bgen
# mypos.9.log
# mypos.txt

# %%
dx upload SNPdata.tgz
# Out:
# [===========================================================>] Uploaded 17,487,601 of 17,487,601 bytes (100%) SNPdata.tgz
# ID                    file-GGkBGQ0J13J7PKvkPV2x8ZgZ
# Class                 file
# Project               project-G6v874QJ13J49Z2B0gz538G2
# Folder                /
# Name                  SNPdata.tgz
# State                 closing
# Visibility            visible
# Types                 -
# Properties            -
# Tags                  -
# Outgoing links        -
# Created               Tue Sep 27 07:29:04 2022
# Created by            ksuhre
#  via the job          job-GGkB2y0J13J6432g9869XFjb
# Last modified         Tue Sep 27 07:29:06 2022
# Media type
# archivalState         "live"
# cloudAccount          "cloudaccount-dnanexus"
